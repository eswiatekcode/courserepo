# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Swiatek Ewa**
# Data Scientist

# %% [markdown]
# *I'am interested in data science, because I love numbers, statistics and convinient live.*

# %% [markdown]
# ### My code will add two to two

# %%
2+2
# Out:
# 4

# %% [markdown]
# ____
# Was it easy?
# * Yes
# * No
#
# [for more view Coursera](https://www.coursera.org)
